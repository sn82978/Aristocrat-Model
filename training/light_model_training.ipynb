# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, MultiHeadAttention, LayerNormalization, Add, Dense, Dropout, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
import pandas as pd

# %% [markdown]
# ## Training

# %%
# positional encoding layer - used  to provide positional information to the model by adding position-dependent signals to word embeddings, 
# allowing the model to incorporate the order of words in the input sequence
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, seq_len, embed_dim):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(seq_len, embed_dim)
    
    def get_angles(self, pos, i, embed_dim):
        angle_rates = 1 / np.power(10000, (2 * (i // 2)) / np.float32(embed_dim))
        return pos * angle_rates
    
    def positional_encoding(self, seq_len, embed_dim):
        angle_rads = self.get_angles(np.arange(seq_len)[:, np.newaxis],
                                     np.arange(embed_dim)[np.newaxis, :], embed_dim)
        angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
        angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
        pos_encoding = angle_rads[np.newaxis, ...]
        return tf.cast(pos_encoding, dtype=tf.float32)
    
    def call(self, x):
        return x + self.pos_encoding[:, :tf.shape(x)[1], :]

# %% [markdown]
# Encoder-Decoder Model

# %%
def build_transformer_model(vocab_size, seq_len, embed_dim=128, num_heads=4, ff_dim=512, num_layers=4, dropout_rate=0.1):
    encoder_inputs = Input(shape=(seq_len,))
    x = Embedding(input_dim=vocab_size, output_dim=embed_dim)(encoder_inputs)
    x = PositionalEncoding(seq_len, embed_dim)(x)
    
    for _ in range(num_layers):
        attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(x, x)
        attention_output = Dropout(dropout_rate)(attention_output)
        attention_output = LayerNormalization()(Add()([x, attention_output]))
        
        ff_output = Dense(ff_dim, activation='relu')(attention_output)
        ff_output = Dense(embed_dim)(ff_output)
        ff_output = Dropout(dropout_rate)(ff_output)
        x = LayerNormalization()(Add()([attention_output, ff_output]))
    encoder_outputs = x
    
    decoder_inputs = Input(shape=(seq_len,))
    y = Embedding(input_dim=vocab_size, output_dim=embed_dim)(decoder_inputs)
    y = PositionalEncoding(seq_len, embed_dim)(y)
    
    for _ in range(num_layers):
        masked_attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(y, y)
        masked_attention_output = Dropout(dropout_rate)(masked_attention_output)
        masked_attention_output = LayerNormalization()(Add()([y, masked_attention_output]))
        
        cross_attention_output = MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)(masked_attention_output, encoder_outputs)
        cross_attention_output = Dropout(dropout_rate)(cross_attention_output)
        y = LayerNormalization()(Add()([masked_attention_output, cross_attention_output]))
        
        ff_output = Dense(ff_dim, activation='relu')(y)
        ff_output = Dense(embed_dim)(ff_output)
        ff_output = Dropout(dropout_rate)(ff_output)
        y = LayerNormalization()(Add()([y, ff_output]))
    
    outputs = TimeDistributed(Dense(vocab_size, activation='softmax'))(y)
    
    model = Model([encoder_inputs, decoder_inputs], outputs)
    return model

# %% [markdown]
# Setting Up Data

# %%
# pruned + combined data
df = pd.read_csv('/Users/shreyanakum/Downloads/Sophomore Year/Summer 2024/Aristocrat-Model/data_collection/pruned_substitution_cipher_dataset_merged.csv')

ciphertexts = df['ciphertext']
plaintexts = df['plaintext']

# %%
# tokenize the sequences
tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(ciphertexts + plaintexts)

# convert text to sequences of integers
ciphertext_sequences = tokenizer.texts_to_sequences(ciphertexts)
plaintext_sequences = tokenizer.texts_to_sequences(plaintexts)

# get the vocabulary size
vocab_size = len(tokenizer.word_index) + 1  # +1 for padding token

# pad the sequences
max_len = max(len(seq) for seq in ciphertext_sequences + plaintext_sequences)
max_len = min(max_len, 100)

# %%
ciphertext_sequences = pad_sequences(ciphertext_sequences, maxlen=max_len, padding='post')
plaintext_sequences = pad_sequences(plaintext_sequences, maxlen=max_len, padding='post')
y_input = pad_sequences(plaintext_sequences[:, :-1], maxlen=max_len, padding='post', value=0)  
y_output = pad_sequences(plaintext_sequences[:, 1:], maxlen=max_len, padding='post', value=0)

# %% [markdown]
# Actual Training
# - Implemented Early Stopping for when the accuracy plateus
# - teacher stopping

# %%
# build and compile the model
model = build_transformer_model(vocab_size, max_len)
model.compile(optimizer=Adam(learning_rate=1e-4), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 100, 128)  │      4,736 │ input_layer_2[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 100, 128)  │          0 │ embedding_2[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 100, 128)  │          0 │ positional_encod… │
# │                     │                   │            │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 100, 128)  │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_36[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 100, 128)  │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_37[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_24[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 100, 128)  │          0 │ dense_22[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_25[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ input_layer_3       │ (None, 100)       │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 100, 128)  │      4,736 │ input_layer_3[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_26[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ positional_encodin… │ (None, 100, 128)  │          0 │ embedding_3[0][0] │
# │ (PositionalEncodin… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ positional_encod… │
# │ (MultiHeadAttentio… │                   │            │ positional_encod… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_24 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_23[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_45          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 100, 128)  │          0 │ dense_24[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_28 (Add)        │ (None, 100, 128)  │          0 │ positional_encod… │
# │                     │                   │            │ dropout_45[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_43[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_28[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_27[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_47          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_29 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_47[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_29[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_25 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_26 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_25[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 100, 128)  │          0 │ dense_26[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_30 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_48[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_30[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_31 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_50[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_31[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_32 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_52[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_32[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_27 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_27[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 100, 128)  │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_33 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_53[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_33[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_34 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_55[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_34[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_57          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_35 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_57[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_35[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_29[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 100, 128)  │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_36 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_58[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_36[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_60          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_37 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_60[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_37[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 100, 128)  │    263,808 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_62          │ (None, 100, 128)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_38 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_62[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_38[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 100, 512)  │     66,048 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 100, 128)  │     65,664 │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_63          │ (None, 100, 128)  │          0 │ dense_32[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_39 (Add)        │ (None, 100, 128)  │          0 │ layer_normalizat… │
# │                     │                   │            │ dropout_63[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 100, 128)  │        256 │ add_39[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_1  │ (None, 100, 37)   │      4,773 │ layer_normalizat… │
# │ (TimeDistributed)   │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,238,757 (16.17 MB)
#  Trainable params: 4,238,757 (16.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(
    monitor='val_accuracy',
    patience=3,              # num of epochs with no improvement after which training will be stopped
    restore_best_weights=True
)

tensorboard_callback = TensorBoard(log_dir="./logs")

# teacher forcing and earlyStopping
model.fit(
    [ciphertext_sequences, y_input], 
    y_output, 
    epochs=10,
    batch_size=16, 
    validation_split=0.2, 
    callbacks=[early_stopping, tensorboard_callback]
)
# Out:
# Epoch 1/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1781s 521ms/step - accuracy: 0.5479 - loss: 1.5851 - val_accuracy: 0.9973 - val_loss: 0.0099
# Epoch 2/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1745s 515ms/step - accuracy: 0.9972 - loss: 0.0104 - val_accuracy: 0.9983 - val_loss: 0.0058
# Epoch 3/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1739s 513ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9985 - val_loss: 0.0053
# Epoch 4/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1730s 510ms/step - accuracy: 0.9986 - loss: 0.0051 - val_accuracy: 0.9988 - val_loss: 0.0042
# Epoch 5/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1585s 467ms/step - accuracy: 0.9987 - loss: 0.0043 - val_accuracy: 0.9989 - val_loss: 0.0039
# Epoch 6/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1522s 449ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9990 - val_loss: 0.0034
# Epoch 7/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1530s 451ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9991 - val_loss: 0.0031
# Epoch 8/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1531s 451ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9991 - val_loss: 0.0032
# Epoch 9/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1533s 452ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9992 - val_loss: 0.0030
# Epoch 10/10
# 3391/3391 ━━━━━━━━━━━━━━━━━━━━ 1536s 453ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9992 - val_loss: 0.0028

# %% [markdown]
# ## After Training Metrics

# %%
# need to add

# %% [markdown]
# ## Testing with Sample Input

# %%
import numpy as np

sample_ciphertext = "LYC EOJZYPA LJC FJUDP LYR JKNTCC FLD GPYFDQ UYPAQTR EOJZYPA JF FLD OTPQTP EJOOJQYGR JPQ FLD NTZJO JOWDNF LJOO."
sample_input_seq = tokenizer.texts_to_sequences([sample_ciphertext])
sample_input_seq = pad_sequences(sample_input_seq, maxlen=max_len, padding='post')

start_token = 0  
decoder_input_seq = np.zeros((1, max_len))
decoder_input_seq[0, 0] = start_token

predicted_text = ""
for i in range(1, max_len):
    predicted_output = model.predict([sample_input_seq, decoder_input_seq])
    next_token = np.argmax(predicted_output[0, i-1, :])
    
    decoder_input_seq[0, i] = next_token
    
    # Debugging: Print token and corresponding character
    print(f"Step {i}: Token={next_token}, Char={tokenizer.sequences_to_texts([[next_token]])[0]}")
    
    predicted_char = tokenizer.sequences_to_texts([[next_token]])[0]
    predicted_text += predicted_char

print("Predicted Text:", predicted_text)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 923ms/step
# Step 1: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 2: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 3: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 4: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 5: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 6: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 7: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 8: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 9: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 10: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 11: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 12: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 13: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 14: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 15: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 16: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 17: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 18: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 19: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 20: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 21: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 22: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 23: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 24: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 25: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 26: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 27: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 28: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 29: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 30: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 31: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 32: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 33: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 34: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 35: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 36: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 37: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 38: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 39: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 40: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 41: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 42: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 43: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 44: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 45: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 46: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 47: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 48: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 49: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 50: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 51: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 52: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Step 53: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 54: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Step 55: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 56: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 57: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 58: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 59: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 60: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 61: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 62: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 63: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 64: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 65: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 66: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 67: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 68: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 69: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Step 70: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 71: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 72: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 73: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 74: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 75: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 76: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 77: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 78: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 79: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 80: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 81: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 82: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 83: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 84: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 85: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 86: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 87: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 88: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Step 89: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 90: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 91: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 92: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 93: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 94: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Step 95: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 96: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Step 97: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 98: Token=0, Char=
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Step 99: Token=0, Char=
# Predicted Text:
